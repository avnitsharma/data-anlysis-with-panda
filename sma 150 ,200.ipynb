# %%
import pandas as pd
import numpy as np
import quandl
import matplotlib.pyplot as plt

# %%
#importing data
quandl.ApiConfig.api_key = 'jD-cKoE-gdzKyzyAfqBN'
infy= quandl.get('NSE/infy', start_date='2000-01-13', end_date='2018-06-13')
infy.head(5)    #looks good
# Out:
#                Open     High     Low    Last    Close  Total Trade Quantity  \
# Date
# 2011-06-29  2868.00  2907.00  2868.0  2880.0  2881.75              600094.0
# 2011-06-30  2886.05  2919.00  2881.5  2903.1  2910.45             1417730.0
# 2011-07-01  2935.00  2969.95  2924.1  2928.0  2934.15              800308.0
# 2011-07-04  2966.65  2977.00  2935.0  2941.0  2938.95              514324.0
# 2011-07-05  2957.00  2969.90  2926.0  2959.0  2956.45              802966.0
#
#             Turnover (Lacs)
# Date
# 2011-06-29         17320.05
# 2011-06-30         41163.32
# 2011-07-01         23549.85
# 2011-07-04         15162.29
# 2011-07-05         23701.22

# %%
infy['Close'].plot(grid=True,figsize=(7,4)) #beauti

# %%
#making sma and storing it into the main data too
infy['150d'] = np.round(infy['Close'].rolling(window=150).mean(),2)
infy['200d'] = np.round(infy['Close'].rolling(window=200).mean(),2)

# %%
infy[['Close','150d','200d']].plot(grid=True,figsize=(12,9))
